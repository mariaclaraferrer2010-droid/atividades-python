# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaclaraferrer2010-droid/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Olá, mundo!")
print("Curso Técnico em Informática")
# Out:
# Olá, mundo!
# Curso Técnico em Informática

# %%
disciplina = input("Digite o nome da disciplina:")
conteudo = input("Digite o conteúdo estudado:")
atividade = input("Digite o número da atividade:")
print("\n--- Informações da atividade ---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Digite o nome da disciplina:algoritmo
# Digite o conteúdo estudado:python
# Digite o número da atividade:1
#
# --- Informações da atividade ---
# Disciplina: algoritmo
# Conteúdo: python
# Atividade: 1
